# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
google_api_key=os.getenv("GOOGLE_GEMINI_API_KEY")

# %%
if google_api_key=="":
    print("Please set the GOOGLE_GEMINI_API_KEY environment variable")
else:
    print("GOOGLE_GEMINI_API_KEY is found")
# Out:
# GOOGLE_GEMINI_API_KEY is found

# %%
from llama_index.llms.gemini import Gemini

import google.generativeai as genai

from llama_index.core import SimpleDirectoryReader

from llama_index.core import VectorStoreIndex, ServiceContext

from IPython.display import Markdown, display

from llama_index.core.node_parser import SentenceSplitter

from llama_index.core import Settings

from llama_index.core import StorageContext, load_index_from_storage

from llama_index.embeddings.gemini import GeminiEmbedding

# %%
genai.configure(api_key=google_api_key)

# %%
for models in genai.list_models():
    print(models)
# Out:
# Model(name='models/chat-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 Chat (Legacy)',
#       description='A legacy text-only model optimized for chat conversations',
#       input_token_limit=4096,
#       output_token_limit=1024,
#       supported_generation_methods=['generateMessage', 'countMessageTokens'],
#       temperature=0.25,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/text-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 (Legacy)',
#       description='A legacy model that understands text and generates text as an output',
#       input_token_limit=8196,
#       output_token_limit=1024,
#       supported_generation_methods=['generateText', 'countTextTokens', 'createTunedTextModel'],
#       temperature=0.7,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/embedding-gecko-001',
#       base_model_id='',
#       version='001',
#       display_name='Embedding Gecko',
# ...

# %%
for models in genai.list_models():
  if 'generateContent' in models.supported_generation_methods:
    print(models.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental

# %% [markdown]
# text to text (the above models)
# text to video (no cover here)

# %%
documents= SimpleDirectoryReader("./../Data")

# %%
doc=documents.load_data()

# %%
model=Gemini(models='gemini-pro', api_key=google_api_key)

# %%
gemini_embed_model=GeminiEmbedding(model_name="models/embedding-001")

# %%
#build the index directly bcz service context is GIVING error
index = VectorStoreIndex.from_documents(
    doc,
    llm=model,
    embed_model=gemini_embed_model,
    chunk_size=800,
    chunk_overlap=20,
)

# %%
index

# %%
index.storage_context.persist()

# %%
query_engine=index.as_query_engine()

# %%
response=query_engine.query("what are the types of machine learning algorithms?")

# %%
print(response.response)
# Out:
# The primary categories of machine learning algorithms are supervised, unsupervised, and reinforcement learning. Semi-supervised learning is also mentioned as a hybrid approach.

# %%
response2=query_engine.query("what are difference between supervised and unsupervised techniques?")

# %%
print(response2)
# Out:
# Supervised learning uses labeled datasets to train algorithms to classify data or predict outcomes, adjusting its weights until it fits appropriately. Unsupervised learning uses machine learning algorithms to analyze and cluster unlabeled datasets, discovering hidden patterns or data groupings without human intervention.

# %%
response=query_engine.query("why machine learning are used?")

# %%
print(response)
# Out:
# Machine learning is used to make classifications or predictions, uncover key insights in data mining projects, and drive decision making within applications and businesses. It is also used in speech recognition, customer service, computer vision, recommendation engines, robotic process automation, automated stock trading, and fraud detection.
